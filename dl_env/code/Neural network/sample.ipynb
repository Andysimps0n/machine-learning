# %%
import pandas as pd
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
data_full = pd.read_csv('../../data/openpowerlifting.csv')
data = data_full[['BestSquatKg', 'BestDeadliftKg']]
data.shape
# Out:
# (386414, 2)

# %%
data
# Out:
#         BestSquatKg  BestDeadliftKg
# 0             47.63           70.31
# 1            142.88          163.29
# 2            142.88          163.29
# 3               NaN             NaN
# 4               NaN           90.72
# ...             ...             ...
# 386409          NaN          347.50
# 386410          NaN          322.50
# 386411          NaN          367.50
# 386412          NaN          320.00
# 386413          NaN          362.50
#
# [386414 rows x 2 columns]

# %%
data.dropna(axis=0, how='any', inplace=True)
data = data[data["BestSquatKg"] > 0]
data = data[data["BestDeadliftKg"] > 0]
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10264\760610945.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(axis=0, how='any', inplace=True)

# %%
subset = data[['BestSquatKg', 'BestDeadliftKg']].sample(n=200, random_state=42)
subset.shape
# Out:
# (200, 2)

# %%
subset.to_csv("data200.csv", index=False)
