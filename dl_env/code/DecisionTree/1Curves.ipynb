# %%
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# x values
x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x) + np.random.normal(0, 0.2, size=x.shape)  # noise std=0.2

X_train, X_test_valid, y_train, y_test_valid = train_test_split(x, y, test_size=0.3, random_state=39)
X_test, X_valid, y_test, y_valid = train_test_split(X_test_valid, y_test_valid, test_size=0.5, random_state=39)
