# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt     
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('../data/Students Social Media Addiction.csv')
data.hist(figsize=(50, 20))
# Out:
# array([[<AxesSubplot:title={'center':'Student_ID'}>,
#         <AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Avg_Daily_Usage_Hours'}>],
#        [<AxesSubplot:title={'center':'Sleep_Hours_Per_Night'}>,
#         <AxesSubplot:title={'center':'Mental_Health_Score'}>,
#         <AxesSubplot:title={'center':'Conflicts_Over_Social_Media'}>],
#        [<AxesSubplot:title={'center':'Addicted_Score'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
data["Avg_Daily_Usage_Hours_cat"] = pd.cut(data["Avg_Daily_Usage_Hours"], bins=[0, 3, 5, 7, np.inf], labels=[1, 2, 3, 4])
data["Avg_Daily_Usage_Hours_cat"].hist()
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# Stratified Split
stratified_split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=3)
for train_index, test_index in stratified_split.split(data, data["Avg_Daily_Usage_Hours_cat"]):
    strat_train_set = data.loc[train_index]
    strat_test_set = data.loc[test_index]

# %%
from sklearn.model_selection import train_test_split


# Random Split
random_split = train_test_split(data, test_size=0.2, train_size=0.8)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9592\1964006984.py in <module>
#       4 # Random Split
#       5 random_split = train_test_split(data, test_size=0.2, train_size=0.8)
# ----> 6 random_split.hist()
#
# AttributeError: 'list' object has no attribute 'hist'
