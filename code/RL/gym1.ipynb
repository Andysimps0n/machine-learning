# %%
import gym
exv = gym.make("CartPole-v1")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3224\4126381323.py in <module>
# ----> 1 import gym
#       2 exv = gym.make("CartPole-v1")
#
# ModuleNotFoundError: No module named 'gym'
