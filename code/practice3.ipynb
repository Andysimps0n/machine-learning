# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt     
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit

data = pd.read_csv('../data/housing.csv')

# median_income => median_house_value

# %%
# Splitting the data

data['median_income_cat'] = pd.qcut(data["median_income"], q=5, labels=False)
data_splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=3)

for train_index, test_index in data_splitter.split(data, data["median_income_cat"]):
    strat_train_set = data.loc[train_index]
    strat_test_set = data.loc[test_index]

# %%
# Detatching the target value
housing = strat_train_set.drop("median_house_value", axis=1)
housing_labes = strat_train_set["median_house_value"].copy()

housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6964     -118.06     33.99                47.0       1588.0           309.0
# 19335    -122.85     38.52                13.0       4808.0           848.0
# 488      -122.26     37.86                52.0       2888.0           604.0
# 19072    -122.49     38.32                30.0       1631.0           284.0
# 675      -122.17     37.69                24.0       2262.0           391.0
# ...          ...       ...                 ...          ...             ...
# 14043    -117.14     32.76                35.0       2539.0           661.0
# 9524     -123.17     39.18                14.0       2240.0           327.0
# 16951    -122.34     37.52                34.0       3559.0           560.0
# 16526    -121.20     37.80                37.0        311.0            61.0
# 15453    -117.31     33.16                17.0       1704.0           263.0
#
#        population  households  median_income ocean_proximity  \
# 6964        827.0       292.0         3.7833       <1H OCEAN
# 19335      2568.0       762.0         3.6583       <1H OCEAN
# 488        1253.0       538.0         3.3893        NEAR BAY
# 19072       788.0       284.0         3.3098       <1H OCEAN
# 675        1125.0       366.0         4.7609        NEAR BAY
# ...           ...         ...            ...             ...
# 14043      1308.0       629.0         2.6777      NEAR OCEAN
# 9524       1030.0       308.0         5.9585       <1H OCEAN
# 16951      1747.0       550.0         6.6959      NEAR OCEAN
# 16526       171.0        54.0         4.0972          INLAND
# 15453       781.0       281.0         5.6605      NEAR OCEAN
#
#        median_income_cat
# 6964                   2
# 19335                  2
# 488                    2
# 19072                  2
# 675                    3
# ...                  ...
# 14043                  1
# 9524                   4
# 16951                  4
# 16526                  3
# 15453                  4
#
# [16512 rows x 10 columns]

# %%
# OneHot Encoding

from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(sparce=False)
housing_cat = housing[['ocean_proximity']]

housing_cat

# oneHotEncoder = OneHotEncoder(sparse=False)
# housing_cat_oneHot = oneHotEncoder.fit_transform(housing_cat) 
# housing_cat_oneHot
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8512\987542596.py in <module>
#       3 from sklearn.preprocessing import OneHotEncoder
#       4
# ----> 5 encoder = OneHotEncoder(sparce=False)
#       6 housing_cat = housing[['ocean_proximity']]
#       7
#
# TypeError: __init__() got an unexpected keyword argument 'sparce'

# %%
# Pipeline : imputer, scaler
